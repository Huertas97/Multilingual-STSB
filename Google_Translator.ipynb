# %% [markdown]
# <a href="https://colab.research.google.com/github/Huertas97/Multilingual-STSB/blob/main/Google_Translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Google dispone de la API Translator a través de Google Cloud. Sin embargo, este servicio tiene costes y limitaciones en el número de carácteres y número de traducciones a realizar: [Link](https://cloud.google.com/translate/docs/resources)
#
# Tenemos otras opciones para emplear Google Translator a través del servicio web. Para las distintas soluciones que propongo paso también el estado del paquete según Snyk Open Source Advisor

# %% [markdown]
# # MTranslate
# Fully working Google Translate API for python 2.7 and 3.x
#
# ![imagen.png](data:image/png;base64,...)

# %%
# !pip install mtranslate
# Out:
# ...
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3694 sha256=826c1db925dfc1c283206d16b9137501c4d45f0acce190d4bf977a420989431e
#   Stored in directory: /root/.cache/pip/wheels/a4/5d/18/6ea549ba042f5f29728049065bdc8a5cdb3c88a413bb026c9a
# Successfully built mtranslate
# ...

# %%
from mtranslate import translate

translate(to_translate = "keep it up, you are awesome", to_language = "es", from_language = "auto"  )
# Out:
# 'sigue así, eres increíble'

# %% [markdown]
# # [Deep Translator](https://pypi.org/project/deep-translator/) (recomendado)
#
# ![imagen.png](data:image/png;base64,...)

# %%
# !pip install -U deep-translator
# Out:
# ...
#      |████████████████████████████████| 97 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 97 kB 5.5 MB/s
# ...
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.0.1 which is incompatible.
# ...

# %% [markdown]
# ### Google Translator

# %%
from deep_translator import GoogleTranslator
# Sentence to translate
s = "keep it up, you are awesome"
# Translators
Google_trans = GoogleTranslator(source='auto', target='es').translate(s) 


print(f"Original sentence >>> {s}")
print(f"Google Translator >>> {Google_trans}")
# Out:
# Original sentence >>> keep it up, you are awesome
# Google Translator >>> sigue así, eres increíble

# %% [markdown]
# ### DeepL
#
# In order to use the DeepL translator, you need to generate an api key. Deepl offers a Pro and a free API. deep-translator supports both Pro and free APIs. Just check the examples below. Visit https://www.deepl.com/en/docs-api/ for more information on how to generate your Deepl api key
#
# DeepL free API use conditions:
#
# Your subscription to DeepL API Free is completely free.
# You can translate up to 500,000 characters per month.
# You can upgrade to DeepL API Pro at any time

# %%
# Get your API key
with open("DeepL_key.txt", "r") as f:
  k = f.readlines()[0].strip()

# %%
from deep_translator import DeepL
DeepL_trans = DeepL(api_key=k, source="en", target="es", use_free_api=True).translate(s)
print(f"Original sentence >>> {s}")
print(f"DeepL Translator >>> {DeepL_trans}")
# Out:
# Original sentence >>> keep it up, you are awesome
# DeepL Translator >>> Sigue así, eres increíble
